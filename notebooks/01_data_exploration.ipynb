# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/Breast_Cancer.csv")

# %%
print("=== FIRST 5 ROWS OF THE DATASET ===")
print("Each row is one patient. Each column is one clinical measurement.")
print()
print(df.head())

print()
print("=== SHAPE OF THE DATASET ===")
print("Format is (number of patients, number of columns.)")
print()
print(df.shape)

print()
print("=== COLUMN NAMES ===")
print("These are all the features available for eacth patient.")
print()
print(df.columns.tolist())

print()
print("=== DATA TYPES OF EACH COLUMN ===")
print("This tells us which columns are numbers and which are text categories.")
print()
print(df.dtypes)

print()
print("=== MISSING VALUES PER COLUMN ===")
print("Any column with a number above 0 has missing data we need to handle.")
print()
print(df.isnull().sum())

print()
print("=== TARGET VARIABLE DISTRIBUTION ===")
print("This shows how many patients are Alive or Dead in our dataset.")
print()
print(df["Status"].value_counts())
# Out:
# === FIRST 5 ROWS OF THE DATASET ===
# Each row is one patient. Each column is one clinical measurement.
#
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# ...
